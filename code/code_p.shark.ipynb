# %%
import pandas as pd
import numpy as np
import zipfile

pd.set_option('display.max_columns', None)

# %%
zip_file = zipfile.ZipFile('archive.zip')

zip_ori = pd.read_csv(zip_file.open('attacks.csv'), encoding= "ISO-8859-1")

zip = zip_ori.copy()

zip.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# ...

# %% [markdown]
# **Limpiar Formato de Datos**

# %%
zip.columns = [e.lower().replace(' ', '') for e in zip.columns]

zip.columns
# Out:
# Index(['casenumber', 'date', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'sex', 'age', 'injury', 'fatal(y/n)', 'time',
#        'species', 'investigatororsource', 'pdf', 'hrefformula', 'href',
#        'casenumber.1', 'casenumber.2', 'originalorder', 'unnamed:22',
#        'unnamed:23'],
#       dtype='object')

# %% [markdown]
# **EDA**
#
# Se da comienzo a la exploracion de los datos.

# %%
zip.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   casenumber            8702 non-null   object
#  1   date                  6302 non-null   object
#  2   year                  6300 non-null   float64
#  3   type                  6298 non-null   object
#  4   country               6252 non-null   object
#  5   area                  5847 non-null   object
#  6   location              5762 non-null   object
#  7   activity              5758 non-null   object
#  8   name                  6092 non-null   object
#  9   sex                   5737 non-null   object
#  10  age                   3471 non-null   object
#  11  injury                6274 non-null   object
#  12  fatal(y/n)            5763 non-null   object
#  13  time                  2948 non-null   object
#  14  species               3464 non-null   object
# ...

# %%
zip.describe(include='all').T
# Out:
#                        count unique  \
# casenumber              8702   6287
# date                    6302   5433
# year                  6300.0    NaN
# type                    6298      8
# country                 6252    212
# area                    5847    825
# location                5762   4108
# activity                5758   1532
# name                    6092   5230
# sex                     5737      6
# age                     3471    157
# injury                  6274   3737
# fatal(y/n)              5763      8
# time                    2948    366
# species                 3464   1549
# investigatororsource    6285   4969
# pdf                     6302   6291
# hrefformula             6301   6290
# href                    6302   6285
# casenumber.1            6302   6285
# casenumber.2            6302   6286
# originalorder         6309.0    NaN
# unnamed:22                 1      1
# unnamed:23                 2      2
#
# ...

# %%
zip.shape
# Out:
# (25723, 24)

# %% [markdown]
# **Columnas numericas**

# %%
zip.select_dtypes(include=['float' , 'int'])
# Out:
#          year  originalorder
# 0      2018.0         6303.0
# 1      2018.0         6302.0
# 2      2018.0         6301.0
# 3      2018.0         6300.0
# 4      2018.0         6299.0
# ...       ...            ...
# 25718     NaN            NaN
# 25719     NaN            NaN
# 25720     NaN            NaN
# 25721     NaN            NaN
# 25722     NaN            NaN
#
# [25723 rows x 2 columns]

# %%
zip._get_numeric_data().head()
# Out:
#      year  originalorder
# 0  2018.0         6303.0
# 1  2018.0         6302.0
# 2  2018.0         6301.0
# 3  2018.0         6300.0
# 4  2018.0         6299.0

# %% [markdown]
# **Columnas categoricas**

# %%
zip.select_dtypes(include='object').head()
# Out:
#    casenumber         date        type    country             area  \
# 0  2018.06.25  25-Jun-2018     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018    Provoked     MEXICO           Colima
#
#                          location     activity             name sex  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN
#
#                                               injury fatal(y/n)  \
# ...

# %% [markdown]
# **Valores Duplicados**

# %%
zip.duplicated().sum()
# Out:
# 19411

# %%
zip = zip.dropna(how='all')

# %%
zip_ori.shape, zip.shape
# Out:
# ((25723, 24), (8703, 24))

# %%
zip.duplicated().sum()
# Out:
# 2392

# %%
zip = zip.drop_duplicates()

# %%
zip_ori.shape, zip.shape
# Out:
# ((25723, 24), (6311, 24))

# %% [markdown]
# **Valores Nulos**

# %%
def check_nan(x) -> None:
    
    nan_cols = zip.isna().sum() 

    display(f'N nan cols: {len(nan_cols[nan_cols>0])}')
    display(nan_cols[nan_cols>0])

# %%
check_nan(zip)
# Out:
# 'N nan cols: 24'
# casenumber                 1
# date                       9
# year                      11
# type                      13
# country                   59
# area                     464
# location                 549
# activity                 553
# name                     219
# sex                      574
# age                     2840
# injury                    37
# fatal(y/n)               548
# time                    3363
# species                 2847
# investigatororsource      26
# pdf                        9
# hrefformula               10
# href                       9
# casenumber.1               9
# casenumber.2               9
# originalorder              2
# unnamed:22              6310
# unnamed:23              6309
# dtype: int64

# %%
zip.tail()
# Out:
#       casenumber date  year type country area location activity name  sex  \
# 6306           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6307           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6308           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6309           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722         xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        age injury fatal(y/n) time species investigatororsource  pdf  \
# 6306   NaN    NaN        NaN  NaN     NaN                  NaN  NaN
# 6307   NaN    NaN        NaN  NaN     NaN                  NaN  NaN
# 6308   NaN    NaN        NaN  NaN     NaN                  NaN  NaN
# 6309   NaN    NaN        NaN  NaN     NaN                  NaN  NaN
# 25722  NaN    NaN        NaN  NaN     NaN                  NaN  NaN
#
#       hrefformula href casenumber.1 casenumber.2  originalorder unnamed:22  \
# ...

# %%
zip.drop([25722], axis= 0, inplace = True)

# %%
zip.set_index(zip.originalorder)
# Out:
#                casenumber         date    year        type    country  \
# originalorder
# 6303.0         2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 6302.0         2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 6301.0         2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 6300.0         2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 6299.0         2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...                   ...          ...     ...         ...        ...
# 6307.0                  0          NaN     NaN         NaN        NaN
# 6308.0                  0          NaN     NaN         NaN        NaN
# 6309.0                  0          NaN     NaN         NaN        NaN
# 6310.0                  0          NaN     NaN         NaN        NaN
# NaN                     0          NaN     NaN         NaN        NaN
#
#                           area                        location     activity  \
# originalorder
# ...

# %%
zip.tail(20)
# Out:
#      casenumber                date  year        type             country  \
# 6290    ND.0012  Before 19-Jul-1913   0.0  Unprovoked        SOUTH AFRICA
# 6291    ND.0011         Before 1911   0.0  Unprovoked               ASIA?
# 6292    ND.0010          Circa 1862   0.0  Unprovoked                 USA
# 6293    ND.0009         Before 1906   0.0  Unprovoked           AUSTRALIA
# 6294    ND.0008         Before 1906   0.0  Unprovoked           AUSTRALIA
# 6295    ND.0007         Before 1906   0.0  Unprovoked           AUSTRALIA
# 6296    ND.0006         Before 1906   0.0  Unprovoked           AUSTRALIA
# 6297    ND.0005         Before 1903   0.0  Unprovoked           AUSTRALIA
# 6298    ND.0004         Before 1903   0.0  Unprovoked           AUSTRALIA
# 6299    ND.0003           1900-1905   0.0  Unprovoked                 USA
# 6300    ND.0002           1883-1889   0.0  Unprovoked              PANAMA
# 6301    ND.0001           1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
# ...

# %%
zip.drop(index=[6302, 6303, 6304, 6305, 6306, 6307, 6308, 6309], inplace= True)

# %%
zip.tail(10)
# Out:
#      casenumber         date  year        type             country  \
# 6292    ND.0010   Circa 1862   0.0  Unprovoked                 USA
# 6293    ND.0009  Before 1906   0.0  Unprovoked           AUSTRALIA
# 6294    ND.0008  Before 1906   0.0  Unprovoked           AUSTRALIA
# 6295    ND.0007  Before 1906   0.0  Unprovoked           AUSTRALIA
# 6296    ND.0006  Before 1906   0.0  Unprovoked           AUSTRALIA
# 6297    ND.0005  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6298    ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6299    ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6300    ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6301    ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    area                             location      activity  \
# 6292             Hawaii                                 Puna           NaN
# 6293                NaN                                  NaN       Fishing
# ...

# %%
check_nan(zip)
# Out:
# 'N nan cols: 18'
# casenumber                 1
# year                       2
# type                       4
# country                   50
# area                     455
# location                 540
# activity                 544
# name                     210
# sex                      565
# age                     2831
# injury                    28
# fatal(y/n)               539
# time                    3354
# species                 2838
# investigatororsource      17
# hrefformula                1
# unnamed:22              6301
# unnamed:23              6300
# dtype: int64

# %%
zip['unnamed:23'].fillna('NoData', inplace=True)
zip['unnamed:22'].fillna('NoData', inplace=True)
zip.hrefformula.fillna('NoURL', inplace=True)
zip.investigatororsource.fillna('NoData', inplace=True)
zip.species.fillna('Unknow', inplace=True)
zip.type.fillna('Unknow', inplace=True)
zip.year.fillna(0.,inplace=True)
zip.country.fillna('Unknow', inplace=True)
zip.area.fillna('Unknow', inplace=True)
zip.location.fillna('Unknow', inplace=True)
zip.activity.fillna('Unknow', inplace=True)

# %%
check_nan(zip)
# Out:
# 'N nan cols: 12'
# casenumber       1
# year             2
# country         50
# area           455
# location       540
# activity       544
# name           210
# sex            565
# age           2831
# injury          28
# fatal(y/n)     539
# time          3354
# dtype: int64

# %%
zip['sex'].isnull().value_counts()
# Out:
# False    5737
# True      565
# Name: sex, dtype: int64
